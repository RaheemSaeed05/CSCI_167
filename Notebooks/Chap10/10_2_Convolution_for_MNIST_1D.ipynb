# %% [markdown]
# <a href="https://colab.research.google.com/github/RaheemSaeed05/CSCI_167/blob/main/Notebooks/Chap10/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-577ai1io
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-577ai1io
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=cb41131744dc600c23339b5eed82d20efcac7401fd52aa80a924a8aae6a632a4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dca9r8tr/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(
    nn.Conv1d(1, 15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),
    nn.Conv1d(15, 15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),
    nn.Conv1d(15, 15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(60, 10)
)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 1.976220, train error 79.22,  val loss 1.972038, percent error 78.90
# Epoch     1, train loss 1.614888, train error 65.18,  val loss 1.632281, percent error 66.90
# Epoch     2, train loss 1.407065, train error 56.75,  val loss 1.425083, percent error 58.60
# Epoch     3, train loss 1.309375, train error 53.30,  val loss 1.323546, percent error 55.40
# Epoch     4, train loss 1.225675, train error 50.62,  val loss 1.246553, percent error 51.10
# Epoch     5, train loss 1.155045, train error 49.10,  val loss 1.188516, percent error 50.90
# Epoch     6, train loss 1.099412, train error 43.65,  val loss 1.120367, percent error 46.60
# Epoch     7, train loss 1.152600, train error 47.45,  val loss 1.183799, percent error 48.60
# Epoch     8, train loss 1.055593, train error 41.55,  val loss 1.099716, percent error 44.00
# Epoch     9, train loss 0.877254, train error 34.25,  val loss 0.926442, percent error 35.60
# Epoch    10, train loss 0.883060, train error 35.28,  val loss 0.940492, percent error 35.90
# Epoch    11, train loss 0.746158, train error 28.80,  val loss 0.814438, percent error 31.80
# Epoch    12, train loss 0.677939, train error 25.90,  val loss 0.744120, percent error 30.20
# Epoch    13, train loss 0.628749, train error 24.22,  val loss 0.687480, percent error 26.80
# Epoch    14, train loss 0.581809, train error 21.32,  val loss 0.627962, percent error 24.90
# Epoch    15, train loss 0.572108, train error 22.07,  val loss 0.648188, percent error 25.20
# Epoch    16, train loss 0.485955, train error 18.72,  val loss 0.574801, percent error 22.90
# Epoch    17, train loss 0.461309, train error 17.10,  val loss 0.545817, percent error 19.30
# Epoch    18, train loss 0.371494, train error 13.57,  val loss 0.484427, percent error 17.90
# Epoch    19, train loss 0.343264, train error 12.90,  val loss 0.433196, percent error 15.50
# Epoch    20, train loss 0.287265, train error 9.90,  val loss 0.412657, percent error 15.80
# Epoch    21, train loss 0.247646, train error 8.57,  val loss 0.361702, percent error 12.80
# Epoch    22, train loss 0.264674, train error 8.75,  val loss 0.373210, percent error 12.80
# Epoch    23, train loss 0.228382, train error 7.80,  val loss 0.341871, percent error 11.90
# Epoch    24, train loss 0.210434, train error 7.15,  val loss 0.309834, percent error 11.20
# Epoch    25, train loss 0.223836, train error 7.78,  val loss 0.361057, percent error 12.20
# Epoch    26, train loss 0.186244, train error 6.00,  val loss 0.302209, percent error 10.50
# Epoch    27, train loss 0.189057, train error 6.60,  val loss 0.307690, percent error 12.10
# Epoch    28, train loss 0.191020, train error 6.72,  val loss 0.305181, percent error 11.50
# Epoch    29, train loss 0.159436, train error 5.30,  val loss 0.292440, percent error 10.90
# Epoch    30, train loss 0.174653, train error 6.40,  val loss 0.294689, percent error 11.10
# Epoch    31, train loss 0.186001, train error 6.75,  val loss 0.340415, percent error 12.20
# Epoch    32, train loss 0.138821, train error 4.30,  val loss 0.275601, percent error 9.80
# Epoch    33, train loss 0.168780, train error 5.90,  val loss 0.303405, percent error 11.40
# Epoch    34, train loss 0.130990, train error 3.80,  val loss 0.283664, percent error 9.70
# Epoch    35, train loss 0.136441, train error 4.35,  val loss 0.295009, percent error 10.40
# Epoch    36, train loss 0.128402, train error 4.07,  val loss 0.276054, percent error 8.50
# Epoch    37, train loss 0.120857, train error 3.65,  val loss 0.265801, percent error 9.00
# Epoch    38, train loss 0.111818, train error 3.53,  val loss 0.280372, percent error 10.60
# Epoch    39, train loss 0.110483, train error 3.47,  val loss 0.280886, percent error 8.90
# Epoch    40, train loss 0.102516, train error 2.93,  val loss 0.271593, percent error 8.80
# Epoch    41, train loss 0.107330, train error 3.65,  val loss 0.293536, percent error 9.60
# Epoch    42, train loss 0.091068, train error 2.53,  val loss 0.273533, percent error 9.20
# Epoch    43, train loss 0.086738, train error 2.18,  val loss 0.271958, percent error 8.80
# Epoch    44, train loss 0.091632, train error 2.78,  val loss 0.284007, percent error 9.20
# Epoch    45, train loss 0.085490, train error 2.28,  val loss 0.282457, percent error 9.30
# Epoch    46, train loss 0.090673, train error 2.65,  val loss 0.284068, percent error 9.20
# Epoch    47, train loss 0.086551, train error 2.60,  val loss 0.280392, percent error 9.10
# Epoch    48, train loss 0.078406, train error 1.93,  val loss 0.280208, percent error 8.40
# Epoch    49, train loss 0.077477, train error 1.88,  val loss 0.273316, percent error 9.00
# Epoch    50, train loss 0.076433, train error 2.00,  val loss 0.286293, percent error 9.00
# Epoch    51, train loss 0.075139, train error 2.00,  val loss 0.288271, percent error 9.00
# Epoch    52, train loss 0.080168, train error 2.20,  val loss 0.290866, percent error 9.00
# Epoch    53, train loss 0.068894, train error 1.57,  val loss 0.280612, percent error 8.90
# Epoch    54, train loss 0.078016, train error 2.12,  val loss 0.287951, percent error 9.20
# Epoch    55, train loss 0.067686, train error 1.60,  val loss 0.293418, percent error 9.40
# Epoch    56, train loss 0.064672, train error 1.47,  val loss 0.294841, percent error 9.70
# Epoch    57, train loss 0.064759, train error 1.47,  val loss 0.304995, percent error 9.50
# Epoch    58, train loss 0.068952, train error 1.97,  val loss 0.302448, percent error 9.10
# Epoch    59, train loss 0.064945, train error 1.72,  val loss 0.294720, percent error 8.80
# Epoch    60, train loss 0.058272, train error 1.20,  val loss 0.293643, percent error 8.40
# Epoch    61, train loss 0.057197, train error 1.15,  val loss 0.295920, percent error 8.80
# Epoch    62, train loss 0.058905, train error 1.32,  val loss 0.300452, percent error 8.70
# Epoch    63, train loss 0.055924, train error 1.10,  val loss 0.300878, percent error 8.90
# Epoch    64, train loss 0.056023, train error 1.22,  val loss 0.298564, percent error 8.80
# Epoch    65, train loss 0.055668, train error 1.22,  val loss 0.300494, percent error 8.90
# Epoch    66, train loss 0.053404, train error 1.05,  val loss 0.300801, percent error 8.60
# Epoch    67, train loss 0.054348, train error 1.10,  val loss 0.303403, percent error 8.70
# Epoch    68, train loss 0.052986, train error 1.07,  val loss 0.307589, percent error 8.70
# Epoch    69, train loss 0.051869, train error 1.07,  val loss 0.298991, percent error 8.30
# Epoch    70, train loss 0.053989, train error 1.03,  val loss 0.309345, percent error 8.90
# Epoch    71, train loss 0.051434, train error 0.97,  val loss 0.306478, percent error 8.70
# Epoch    72, train loss 0.050061, train error 1.05,  val loss 0.308697, percent error 8.50
# Epoch    73, train loss 0.050150, train error 0.90,  val loss 0.311632, percent error 9.20
# Epoch    74, train loss 0.048452, train error 0.95,  val loss 0.309003, percent error 8.50
# Epoch    75, train loss 0.048510, train error 0.93,  val loss 0.312540, percent error 8.70
# Epoch    76, train loss 0.047582, train error 0.85,  val loss 0.311859, percent error 8.50
# Epoch    77, train loss 0.047232, train error 0.78,  val loss 0.311110, percent error 8.60
# Epoch    78, train loss 0.049243, train error 0.88,  val loss 0.316912, percent error 8.90
# Epoch    79, train loss 0.047286, train error 0.72,  val loss 0.317239, percent error 8.40
# Epoch    80, train loss 0.045463, train error 0.78,  val loss 0.314656, percent error 8.60
# Epoch    81, train loss 0.045309, train error 0.88,  val loss 0.315051, percent error 8.30
# Epoch    82, train loss 0.044850, train error 0.80,  val loss 0.314943, percent error 8.80
# Epoch    83, train loss 0.044760, train error 0.75,  val loss 0.316289, percent error 8.70
# Epoch    84, train loss 0.044435, train error 0.80,  val loss 0.319108, percent error 8.50
# Epoch    85, train loss 0.044037, train error 0.72,  val loss 0.317879, percent error 8.80
# Epoch    86, train loss 0.043849, train error 0.75,  val loss 0.318382, percent error 8.90
# Epoch    87, train loss 0.044305, train error 0.82,  val loss 0.322177, percent error 8.80
# Epoch    88, train loss 0.044369, train error 0.78,  val loss 0.322431, percent error 8.80
# Epoch    89, train loss 0.043061, train error 0.72,  val loss 0.320235, percent error 8.80
# Epoch    90, train loss 0.043224, train error 0.70,  val loss 0.321178, percent error 8.90
# Epoch    91, train loss 0.042901, train error 0.80,  val loss 0.320171, percent error 9.10
# Epoch    92, train loss 0.042228, train error 0.70,  val loss 0.319736, percent error 8.90
# Epoch    93, train loss 0.042010, train error 0.68,  val loss 0.321244, percent error 8.70
# Epoch    94, train loss 0.042115, train error 0.68,  val loss 0.322755, percent error 9.00
# Epoch    95, train loss 0.042227, train error 0.80,  val loss 0.325364, percent error 8.90
# Epoch    96, train loss 0.041533, train error 0.62,  val loss 0.324193, percent error 8.70
# Epoch    97, train loss 0.041417, train error 0.70,  val loss 0.324897, percent error 8.90
# Epoch    98, train loss 0.040840, train error 0.65,  val loss 0.325151, percent error 8.70
# Epoch    99, train loss 0.041239, train error 0.70,  val loss 0.324994, percent error 9.00
