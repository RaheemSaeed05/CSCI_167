# %% [markdown]
# <a href="https://colab.research.google.com/github/RaheemSaeed05/CSCI_167/blob/main/Notebooks/Chap07/7_3_Initialization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 7.3: Initialization**
#
# This notebook explores weight initialization in deep neural networks as described in section 7.5 of the book.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# First let's define a neural network.  We'll just choose the weights and biases randomly for now

# %%
def init_params(K, D, sigma_sq_omega):
  # Set seed so we always get the same random numbers
  np.random.seed(0)

  # Input layer
  D_i = 1
  # Output layer
  D_o = 1

  # Make empty lists
  all_weights = [None] * (K+1)
  all_biases = [None] * (K+1)

  # Create input and output layers
  all_weights[0] = np.random.normal(size=(D, D_i))*np.sqrt(sigma_sq_omega)
  all_weights[-1] = np.random.normal(size=(D_o, D)) * np.sqrt(sigma_sq_omega)
  all_biases[0] = np.zeros((D,1))
  all_biases[-1]= np.zeros((D_o,1))

  # Create intermediate layers
  for layer in range(1,K):
    all_weights[layer] = np.random.normal(size=(D,D))*np.sqrt(sigma_sq_omega)
    all_biases[layer] = np.zeros((D,1))

  return all_weights, all_biases

# %%
# Define the Rectified Linear Unit (ReLU) function
def ReLU(preactivation):
  activation = preactivation.clip(0.0)
  return activation

# %%
def compute_network_output(net_input, all_weights, all_biases):

  # Retrieve number of layers
  K = len(all_weights)-1

  # We'll store the pre-activations at each layer in a list "all_f"
  # and the activations in a second list "all_h".
  all_f = [None] * (K+1)
  all_h = [None] * (K+1)

  #For convenience, we'll set
  # all_h[0] to be the input, and all_f[K] will be the output
  all_h[0] = net_input

  # Run through the layers, calculating all_f[0...K-1] and all_h[1...K]
  for layer in range(K):
      # Update preactivations and activations at this layer according to eqn 7.5
      all_f[layer] = all_biases[layer] + np.matmul(all_weights[layer], all_h[layer])
      all_h[layer+1] = ReLU(all_f[layer])

  # Compute the output from the last hidden layer
  all_f[K] = all_biases[K] + np.matmul(all_weights[K], all_h[K])

  # Retrieve the output
  net_output = all_f[K]

  return net_output, all_f, all_h

# %% [markdown]
# Now let's investigate how the size of the outputs vary as we change the initialization variance:

# %%
# Number of layers
K = 5
# Number of neurons per layer
D = 8
# Input layer
D_i = 1
# Output layer
D_o = 1
# Set variance of initial weights to 1
sigma_sq_omega = 1.0
# Initialize parameters
all_weights, all_biases = init_params(K,D,sigma_sq_omega)

n_data = 1000
data_in = np.random.normal(size=(1,n_data))
net_output, all_f, all_h = compute_network_output(data_in, all_weights, all_biases)

for layer in range(1,K+1):
  print("Layer %d, std of hidden units = %3.3f"%(layer, np.std(all_h[layer])))
# Out:
# Layer 1, std of hidden units = 0.811
# Layer 2, std of hidden units = 1.472
# Layer 3, std of hidden units = 4.547
# Layer 4, std of hidden units = 8.896
# Layer 5, std of hidden units = 10.106

# %%
# TODO
# Change this to 50 layers with 80 hidden units per layer
K = 50          # number of layers
D = 80          # number of neurons per hidden layer
D_i = 1         # input dim (keep as in notebook)
D_o = 1         # output dim (keep as in notebook)
n_data = 1000

# Helper: run a forward pass and report per-layer std of activations
def report_std_for(sigma_sq_omega, title=None):
    all_weights, all_biases = init_params(K, D, sigma_sq_omega)
    data_in = np.random.normal(size=(D_i, n_data))
    net_output, all_f, all_h = compute_network_output(data_in, all_weights, all_biases)
    if title:
        print(f"\n{title}  (sigma_sq_omega={sigma_sq_omega:.6f})")
    for layer in range(K+1):
        print("Layer %2d, std of hidden units = %.3f" % (layer, np.std(all_h[layer])))

# TODO
# Now experiment with sigma_sq_omega to try to stop the variance of the forward computation exploding
# Try several inits; for ReLU, He init suggests variance ~ 2 / fan_in
report_std_for(1.0,                "Baseline (often explodes)")
report_std_for(1.0 / D,            "Xavier-like (1/fan_in)")
report_std_for(2.0 / D,            "He-like (2/fan_in)  <-- usually stable for ReLU")
report_std_for(2.0 / (D_i + D),    "Scaled by fan_in + fan_out")
# Out:
# Baseline (often explodes)  (sigma_sq_omega=1.000000)
# Layer  0, std of hidden units = 0.981
# Layer  1, std of hidden units = 0.622
# Layer  2, std of hidden units = 3.108
# Layer  3, std of hidden units = 21.075
# Layer  4, std of hidden units = 161.638
# Layer  5, std of hidden units = 1125.582
# Layer  6, std of hidden units = 6319.072
# Layer  7, std of hidden units = 37275.665
# Layer  8, std of hidden units = 243387.814
# Layer  9, std of hidden units = 1339835.231
# Layer 10, std of hidden units = 7366234.399
# Layer 11, std of hidden units = 49006173.785
# Layer 12, std of hidden units = 272845366.658
# Layer 13, std of hidden units = 1682043584.115
# Layer 14, std of hidden units = 10666632256.715
# Layer 15, std of hidden units = 66098343304.232
# Layer 16, std of hidden units = 429669007251.536
# Layer 17, std of hidden units = 2889209957356.916
# Layer 18, std of hidden units = 19621779417283.500
# Layer 19, std of hidden units = 121787762396578.969
# Layer 20, std of hidden units = 999886829483868.875
# Layer 21, std of hidden units = 5334411928004679.000
# Layer 22, std of hidden units = 33827620837739412.000
# Layer 23, std of hidden units = 225444894681278176.000
# Layer 24, std of hidden units = 1627820610460267776.000
# Layer 25, std of hidden units = 11267764649765797888.000
# Layer 26, std of hidden units = 67624804921841573888.000
# Layer 27, std of hidden units = 364972590784171016192.000
# Layer 28, std of hidden units = 2240665662851632070656.000
# Layer 29, std of hidden units = 17591855121671590510592.000
# Layer 30, std of hidden units = 127571735900692099891200.000
# Layer 31, std of hidden units = 673191222755367401291776.000
# Layer 32, std of hidden units = 3013965906952738308096000.000
# Layer 33, std of hidden units = 18058080219374336341966848.000
# Layer 34, std of hidden units = 113844343088523883136942080.000
# Layer 35, std of hidden units = 743768651021983614777688064.000
# Layer 36, std of hidden units = 4212183983909334019905421312.000
# Layer 37, std of hidden units = 29165435896872114952769372160.000
# Layer 38, std of hidden units = 158335947919997755737983942656.000
# Layer 39, std of hidden units = 997715185910698111272413560832.000
# Layer 40, std of hidden units = 6426783972194130038049969537024.000
# Layer 41, std of hidden units = 43768309206637147921539531800576.000
# Layer 42, std of hidden units = 303487129329508551216341155053568.000
# Layer 43, std of hidden units = 1776138313453572474864744603320320.000
# Layer 44, std of hidden units = 11908465022449954960409252809670656.000
# Layer 45, std of hidden units = 89231570537681377058251182172012544.000
# Layer 46, std of hidden units = 537142295281509613087075230529093632.000
# Layer 47, std of hidden units = 3598219068834594188168289796459855872.000
# Layer 48, std of hidden units = 19195733181303612908140446019993206784.000
# Layer 49, std of hidden units = 112209168636519545406961012606813339648.000
# Layer 50, std of hidden units = 753218502856424628936041819469258948608.000
#
# Xavier-like (1/fan_in)  (sigma_sq_omega=0.012500)
# Layer  0, std of hidden units = 0.981
# Layer  1, std of hidden units = 0.070
# Layer  2, std of hidden units = 0.039
# Layer  3, std of hidden units = 0.029
# Layer  4, std of hidden units = 0.025
# Layer  5, std of hidden units = 0.020
# Layer  6, std of hidden units = 0.012
# Layer  7, std of hidden units = 0.008
# Layer  8, std of hidden units = 0.006
# Layer  9, std of hidden units = 0.004
# Layer 10, std of hidden units = 0.002
# Layer 11, std of hidden units = 0.002
# Layer 12, std of hidden units = 0.001
# Layer 13, std of hidden units = 0.001
# Layer 14, std of hidden units = 0.001
# Layer 15, std of hidden units = 0.000
# Layer 16, std of hidden units = 0.000
# Layer 17, std of hidden units = 0.000
# Layer 18, std of hidden units = 0.000
# Layer 19, std of hidden units = 0.000
# Layer 20, std of hidden units = 0.000
# Layer 21, std of hidden units = 0.000
# Layer 22, std of hidden units = 0.000
# Layer 23, std of hidden units = 0.000
# Layer 24, std of hidden units = 0.000
# Layer 25, std of hidden units = 0.000
# Layer 26, std of hidden units = 0.000
# Layer 27, std of hidden units = 0.000
# Layer 28, std of hidden units = 0.000
# Layer 29, std of hidden units = 0.000
# Layer 30, std of hidden units = 0.000
# Layer 31, std of hidden units = 0.000
# Layer 32, std of hidden units = 0.000
# Layer 33, std of hidden units = 0.000
# Layer 34, std of hidden units = 0.000
# Layer 35, std of hidden units = 0.000
# Layer 36, std of hidden units = 0.000
# Layer 37, std of hidden units = 0.000
# Layer 38, std of hidden units = 0.000
# Layer 39, std of hidden units = 0.000
# Layer 40, std of hidden units = 0.000
# Layer 41, std of hidden units = 0.000
# Layer 42, std of hidden units = 0.000
# Layer 43, std of hidden units = 0.000
# Layer 44, std of hidden units = 0.000
# Layer 45, std of hidden units = 0.000
# Layer 46, std of hidden units = 0.000
# Layer 47, std of hidden units = 0.000
# Layer 48, std of hidden units = 0.000
# Layer 49, std of hidden units = 0.000
# Layer 50, std of hidden units = 0.000
#
# He-like (2/fan_in)  <-- usually stable for ReLU  (sigma_sq_omega=0.025000)
# Layer  0, std of hidden units = 0.981
# Layer  1, std of hidden units = 0.098
# Layer  2, std of hidden units = 0.078
# Layer  3, std of hidden units = 0.083
# Layer  4, std of hidden units = 0.101
# Layer  5, std of hidden units = 0.111
# Layer  6, std of hidden units = 0.099
# Layer  7, std of hidden units = 0.092
# Layer  8, std of hidden units = 0.095
# Layer  9, std of hidden units = 0.083
# Layer 10, std of hidden units = 0.072
# Layer 11, std of hidden units = 0.076
# Layer 12, std of hidden units = 0.067
# Layer 13, std of hidden units = 0.065
# Layer 14, std of hidden units = 0.065
# Layer 15, std of hidden units = 0.064
# Layer 16, std of hidden units = 0.066
# Layer 17, std of hidden units = 0.070
# Layer 18, std of hidden units = 0.075
# Layer 19, std of hidden units = 0.073
# Layer 20, std of hidden units = 0.095
# Layer 21, std of hidden units = 0.080
# Layer 22, std of hidden units = 0.081
# Layer 23, std of hidden units = 0.085
# Layer 24, std of hidden units = 0.097
# Layer 25, std of hidden units = 0.106
# Layer 26, std of hidden units = 0.101
# Layer 27, std of hidden units = 0.086
# Layer 28, std of hidden units = 0.083
# Layer 29, std of hidden units = 0.104
# Layer 30, std of hidden units = 0.119
# Layer 31, std of hidden units = 0.099
# Layer 32, std of hidden units = 0.070
# Layer 33, std of hidden units = 0.066
# Layer 34, std of hidden units = 0.066
# Layer 35, std of hidden units = 0.068
# Layer 36, std of hidden units = 0.061
# Layer 37, std of hidden units = 0.067
# Layer 38, std of hidden units = 0.058
# Layer 39, std of hidden units = 0.057
# Layer 40, std of hidden units = 0.058
# Layer 41, std of hidden units = 0.063
# Layer 42, std of hidden units = 0.069
# Layer 43, std of hidden units = 0.064
# Layer 44, std of hidden units = 0.068
# Layer 45, std of hidden units = 0.080
# Layer 46, std of hidden units = 0.076
# Layer 47, std of hidden units = 0.081
# Layer 48, std of hidden units = 0.068
# Layer 49, std of hidden units = 0.063
# Layer 50, std of hidden units = 0.067
#
# Scaled by fan_in + fan_out  (sigma_sq_omega=0.024691)
# Layer  0, std of hidden units = 0.981
# Layer  1, std of hidden units = 0.098
# Layer  2, std of hidden units = 0.077
# Layer  3, std of hidden units = 0.082
# Layer  4, std of hidden units = 0.099
# Layer  5, std of hidden units = 0.108
# Layer  6, std of hidden units = 0.095
# Layer  7, std of hidden units = 0.088
# Layer  8, std of hidden units = 0.090
# Layer  9, std of hidden units = 0.078
# Layer 10, std of hidden units = 0.068
# Layer 11, std of hidden units = 0.071
# Layer 12, std of hidden units = 0.062
# Layer 13, std of hidden units = 0.060
# Layer 14, std of hidden units = 0.060
# Layer 15, std of hidden units = 0.058
# Layer 16, std of hidden units = 0.059
# Layer 17, std of hidden units = 0.063
# Layer 18, std of hidden units = 0.067
# Layer 19, std of hidden units = 0.065
# Layer 20, std of hidden units = 0.084
# Layer 21, std of hidden units = 0.071
# Layer 22, std of hidden units = 0.070
# Layer 23, std of hidden units = 0.074
# Layer 24, std of hidden units = 0.084
# Layer 25, std of hidden units = 0.091
# Layer 26, std of hidden units = 0.086
# Layer 27, std of hidden units = 0.073
# Layer 28, std of hidden units = 0.070
# Layer 29, std of hidden units = 0.087
# Layer 30, std of hidden units = 0.099
# Layer 31, std of hidden units = 0.082
# Layer 32, std of hidden units = 0.058
# Layer 33, std of hidden units = 0.054
# Layer 34, std of hidden units = 0.054
# Layer 35, std of hidden units = 0.055
# Layer 36, std of hidden units = 0.049
# Layer 37, std of hidden units = 0.053
# Layer 38, std of hidden units = 0.045
# Layer 39, std of hidden units = 0.045
# Layer 40, std of hidden units = 0.046
# Layer 41, std of hidden units = 0.049
# Layer 42, std of hidden units = 0.053
# Layer 43, std of hidden units = 0.049
# Layer 44, std of hidden units = 0.052
# Layer 45, std of hidden units = 0.061
# Layer 46, std of hidden units = 0.057
# Layer 47, std of hidden units = 0.060
# Layer 48, std of hidden units = 0.051
# Layer 49, std of hidden units = 0.046
# Layer 50, std of hidden units = 0.049

# %% [markdown]
# Now let's define a loss function.  We'll just use the least squares loss function. We'll also write a function to compute dloss_doutput

# %%
def least_squares_loss(net_output, y):
  return np.sum((net_output-y) * (net_output-y))

def d_loss_d_output(net_output, y):
    return 2*(net_output -y);

# %% [markdown]
# Here's the code for the backward pass

# %%
# We'll need the indicator function
def indicator_function(x):
  x_in = np.array(x)
  x_in[x_in>=0] = 1
  x_in[x_in<0] = 0
  return x_in

# Main backward pass routine
def backward_pass(all_weights, all_biases, all_f, all_h, y):
  # Retrieve number of layers
  K = len(all_weights) - 1

  # We'll store the derivatives dl_dweights and dl_dbiases in lists as well
  all_dl_dweights = [None] * (K+1)
  all_dl_dbiases = [None] * (K+1)
  # And we'll store the derivatives of the loss with respect to the activation and preactivations in lists
  all_dl_df = [None] * (K+1)
  all_dl_dh = [None] * (K+1)
  # Again for convenience we'll stick with the convention that all_h[0] is the net input and all_f[k] in the net output

  # Compute derivatives of net output with respect to loss
  all_dl_df[K] = np.array(d_loss_d_output(all_f[K],y))

  # Now work backwards through the network
  for layer in range(K,-1,-1):
    # Calculate the derivatives of biases at layer from all_dl_df[K]. (eq 7.13, line 1)
    all_dl_dbiases[layer] = np.array(all_dl_df[layer])
    # Calculate the derivatives of weight at layer from all_dl_df[K] and all_h[K] (eq 7.13, line 2)
    all_dl_dweights[layer] = np.matmul(all_dl_df[layer], all_h[layer].transpose())

    # Calculate the derivatives of activations from weight and derivatives of next preactivations (eq 7.13, line 3 second part)
    all_dl_dh[layer] = np.matmul(all_weights[layer].transpose(), all_dl_df[layer])
    # Calculate the derivatives of the pre-activation f with respect to activation h (eq 7.13, line 3, first part)
    if layer > 0:
      all_dl_df[layer-1] = indicator_function(all_f[layer-1]) * all_dl_dh[layer]

  return all_dl_dweights, all_dl_dbiases, all_dl_dh, all_dl_df

# %% [markdown]
# Now let's look at what happens to the magnitude of the gradients on the way back.

# %%
# Number of layers
K = 5
# Number of neurons per layer
D = 8
# Input layer
D_i = 1
# Output layer
D_o = 1
# Set variance of initial weights to 1
sigma_sq_omega = 1.0
# Initialize parameters
all_weights, all_biases = init_params(K,D,sigma_sq_omega)

# For simplicity we'll just consider the gradients of the weights and biases between the first and last hidden layer
n_data = 100
aggregate_dl_df = [None] * (K+1)
for layer in range(1,K):
  # These 3D arrays will store the gradients for every data point
  aggregate_dl_df[layer] = np.zeros((D,n_data))


# We'll have to compute the derivatives of the parameters for each data point separately
for c_data in range(n_data):
  data_in = np.random.normal(size=(1,1))
  y = np.zeros((1,1))
  net_output, all_f, all_h = compute_network_output(data_in, all_weights, all_biases)
  all_dl_dweights, all_dl_dbiases, all_dl_dh, all_dl_df = backward_pass(all_weights, all_biases, all_f, all_h, y)
  for layer in range(1,K):
    aggregate_dl_df[layer][:,c_data] = np.squeeze(all_dl_df[layer])

for layer in range(1,K):
  print("Layer %d, std of dl_dh = %3.3f"%(layer, np.std(aggregate_dl_df[layer].ravel())))
# Out:
# Layer 1, std of dl_dh = 446.654
# Layer 2, std of dl_dh = 340.657
# Layer 3, std of dl_dh = 109.132
# Layer 4, std of dl_dh = 56.472

# %%
# You can see that the gradients of the hidden units are increasing on average (the standard deviation is across all hidden units at the layer
# and the 100 training examples

# TODO
# Change this to 50 layers with 80 hidden units per layer
K = 50            # number of layers
D = 80            # hidden units per layer
D_i, D_o = 1, 1
n_data = 100

# TODO
# Now experiment with sigma_sq_omega to try to stop the variance of the gradients exploding
# (For ReLU, He init ~ 2/fan_in often stabilizes.)
for sigma_sq_omega in [1.0,        # baseline (often explodes)
                       1.0 / D,    # Xavier-like
                       2.0 / D,    # He-like  <-- usually best for ReLU
                       2.0 / (D_i + D)]:  # fan_in + fan_out
    print(f"\n--- sigma_sq_omega = {sigma_sq_omega:.6f} ---")
    # init params and a random batch
    all_weights, all_biases = init_params(K, D, sigma_sq_omega)
    data_in = np.random.normal(size=(D_i, n_data))

    # forward pass
    net_output, all_f, all_h = compute_network_output(data_in, all_weights, all_biases)

    # simple target for squared loss (shape must match output)
    y = np.zeros_like(net_output)

    # backward pass (unpack all four returns)
    all_dl_dweights, all_dl_dbiases, all_dl_dh, all_dl_df = backward_pass(
        all_weights, all_biases, all_f, all_h, y
    )

    # report gradient std per layer (bias grads shown; weights exhibit similar trends)
    for layer in range(K+1):
        print("Layer %2d, std of dl/dbias = %.4f" % (layer, np.std(all_dl_dbiases[layer])))
# Out:
# --- sigma_sq_omega = 1.000000 ---
# Layer  0, std of dl/dbias = 25317286121455479275873085468323424791040361644595985977624104433024300063129600.0000
# Layer  1, std of dl/dbias = 3864161615668243558708988849770883345569582827710374876720361401686977251639296.0000
# Layer  2, std of dl/dbias = 644297462740804610598547067451302999122676082898034536151030348335676055879680.0000
# Layer  3, std of dl/dbias = 116256578506420923819026128549181869661227298447599782554315757230354610520064.0000
# Layer  4, std of dl/dbias = 18012406883088287360944536282611955062753075342737181404368329411698580520960.0000
# Layer  5, std of dl/dbias = 2657382923492154835783232487025270871699950595660933216933447972349422862336.0000
# Layer  6, std of dl/dbias = 437115574218245193807908837898776765075349933300781174644617597538000699392.0000
# Layer  7, std of dl/dbias = 72289425689022358586552980955410893623323940350219372288980937670752468992.0000
# Layer  8, std of dl/dbias = 10229045579369873921342292892226629597219518497812726690429880789446426624.0000
# Layer  9, std of dl/dbias = 1622769590787357025006569195968159167918422581667076386178123155749470208.0000
# Layer 10, std of dl/dbias = 291677266860870437780232576190188443241514488697868118675201045020278784.0000
# Layer 11, std of dl/dbias = 47040925004825703962595186949339722019933455096289284029532727744135168.0000
# Layer 12, std of dl/dbias = 7477794785556511029375003658625364545843316026986261679990214882230272.0000
# Layer 13, std of dl/dbias = 1079960630998983058190224039535382251724367045469961055439948445908992.0000
# Layer 14, std of dl/dbias = 177343205970746323022535267612975334749257408015264898871563036655616.0000
# Layer 15, std of dl/dbias = 29375585020824595876323438882563944622670945766559944750793517694976.0000
# Layer 16, std of dl/dbias = 4228152175740393840420430907377032438398605544578239798569609461760.0000
# Layer 17, std of dl/dbias = 571601369784794802374457841853629406868563622060822340288437551104.0000
# Layer 18, std of dl/dbias = 91625806080021443266251793730777964254284721650597171089696096256.0000
# Layer 19, std of dl/dbias = 12981649213666812547549762085166560510229790072858776566390325248.0000
# Layer 20, std of dl/dbias = 2521931090077675433924889421857101062760364846347211516518858752.0000
# Layer 21, std of dl/dbias = 366590511153710231954281955683022611931922602313136886528344064.0000
# Layer 22, std of dl/dbias = 51359326687770697464108108648085179888607927450632186614513664.0000
# Layer 23, std of dl/dbias = 8400447047412214529915927991501880114551488448829314994012160.0000
# Layer 24, std of dl/dbias = 1167175082942496080766029649745087918256740551241396182319104.0000
# Layer 25, std of dl/dbias = 189303733379321798649172026799523896731941588475235222421504.0000
# Layer 26, std of dl/dbias = 41712815717105567582202429915066996391791998114458492731392.0000
# Layer 27, std of dl/dbias = 5462460278894731362247246681715189166012756981361848352768.0000
# Layer 28, std of dl/dbias = 956779985561020140674147027633381199677921770355854147584.0000
# Layer 29, std of dl/dbias = 163553513870808561742251371104396146561872124897220624384.0000
# Layer 30, std of dl/dbias = 27962097471983037393743458109119075698189900640061227008.0000
# Layer 31, std of dl/dbias = 4533651840178384461262480437643334259175029047440703488.0000
# Layer 32, std of dl/dbias = 692775722996451473506451301136992736123577835657887744.0000
# Layer 33, std of dl/dbias = 115846381203838787394170905633539747898124137758982144.0000
# Layer 34, std of dl/dbias = 20622026877096516274168395047672140496941939104415744.0000
# Layer 35, std of dl/dbias = 3038521358601097647024950608360837004079382839427072.0000
# Layer 36, std of dl/dbias = 486644995502083127708682788488469787451507406274560.0000
# Layer 37, std of dl/dbias = 67762952239536214087718500711727746678730564567040.0000
# Layer 38, std of dl/dbias = 10332488588890049713609937944320962320259371499520.0000
# Layer 39, std of dl/dbias = 1461454311950454403604998671601501964603523858432.0000
# Layer 40, std of dl/dbias = 258241445087590735643133194351627983599477719040.0000
# Layer 41, std of dl/dbias = 40450451143651948074448641170628902477352665088.0000
# Layer 42, std of dl/dbias = 7712581729931044545150107431487218057337634816.0000
# Layer 43, std of dl/dbias = 1336239794865748202433384835430338808200036352.0000
# Layer 44, std of dl/dbias = 231495044789922145345902695211142088107229184.0000
# Layer 45, std of dl/dbias = 39500717745074512367426775088265226423894016.0000
# Layer 46, std of dl/dbias = 5987633018620223252680859241244423494828032.0000
# Layer 47, std of dl/dbias = 966020560711593611954353793080976121790464.0000
# Layer 48, std of dl/dbias = 140118487856732220476770152623959995056128.0000
# Layer 49, std of dl/dbias = 18817849764518896023941902245604242751488.0000
# Layer 50, std of dl/dbias = 14453574238164926241629994332597333786624.0000
#
# --- sigma_sq_omega = 0.012500 ---
# Layer  0, std of dl/dbias = 0.0000
# Layer  1, std of dl/dbias = 0.0000
# Layer  2, std of dl/dbias = 0.0000
# Layer  3, std of dl/dbias = 0.0000
# Layer  4, std of dl/dbias = 0.0000
# Layer  5, std of dl/dbias = 0.0000
# Layer  6, std of dl/dbias = 0.0000
# Layer  7, std of dl/dbias = 0.0000
# Layer  8, std of dl/dbias = 0.0000
# Layer  9, std of dl/dbias = 0.0000
# Layer 10, std of dl/dbias = 0.0000
# Layer 11, std of dl/dbias = 0.0000
# Layer 12, std of dl/dbias = 0.0000
# Layer 13, std of dl/dbias = 0.0000
# Layer 14, std of dl/dbias = 0.0000
# Layer 15, std of dl/dbias = 0.0000
# Layer 16, std of dl/dbias = 0.0000
# Layer 17, std of dl/dbias = 0.0000
# Layer 18, std of dl/dbias = 0.0000
# Layer 19, std of dl/dbias = 0.0000
# Layer 20, std of dl/dbias = 0.0000
# Layer 21, std of dl/dbias = 0.0000
# Layer 22, std of dl/dbias = 0.0000
# Layer 23, std of dl/dbias = 0.0000
# Layer 24, std of dl/dbias = 0.0000
# Layer 25, std of dl/dbias = 0.0000
# Layer 26, std of dl/dbias = 0.0000
# Layer 27, std of dl/dbias = 0.0000
# Layer 28, std of dl/dbias = 0.0000
# Layer 29, std of dl/dbias = 0.0000
# Layer 30, std of dl/dbias = 0.0000
# Layer 31, std of dl/dbias = 0.0000
# Layer 32, std of dl/dbias = 0.0000
# Layer 33, std of dl/dbias = 0.0000
# Layer 34, std of dl/dbias = 0.0000
# Layer 35, std of dl/dbias = 0.0000
# Layer 36, std of dl/dbias = 0.0000
# Layer 37, std of dl/dbias = 0.0000
# Layer 38, std of dl/dbias = 0.0000
# Layer 39, std of dl/dbias = 0.0000
# Layer 40, std of dl/dbias = 0.0000
# Layer 41, std of dl/dbias = 0.0000
# Layer 42, std of dl/dbias = 0.0000
# Layer 43, std of dl/dbias = 0.0000
# Layer 44, std of dl/dbias = 0.0000
# Layer 45, std of dl/dbias = 0.0000
# Layer 46, std of dl/dbias = 0.0000
# Layer 47, std of dl/dbias = 0.0000
# Layer 48, std of dl/dbias = 0.0000
# Layer 49, std of dl/dbias = 0.0000
# Layer 50, std of dl/dbias = 0.0000
#
# --- sigma_sq_omega = 0.025000 ---
# Layer  0, std of dl/dbias = 0.0316
# Layer  1, std of dl/dbias = 0.0305
# Layer  2, std of dl/dbias = 0.0321
# Layer  3, std of dl/dbias = 0.0367
# Layer  4, std of dl/dbias = 0.0359
# Layer  5, std of dl/dbias = 0.0335
# Layer  6, std of dl/dbias = 0.0349
# Layer  7, std of dl/dbias = 0.0365
# Layer  8, std of dl/dbias = 0.0327
# Layer  9, std of dl/dbias = 0.0328
# Layer 10, std of dl/dbias = 0.0373
# Layer 11, std of dl/dbias = 0.0380
# Layer 12, std of dl/dbias = 0.0382
# Layer 13, std of dl/dbias = 0.0349
# Layer 14, std of dl/dbias = 0.0362
# Layer 15, std of dl/dbias = 0.0380
# Layer 16, std of dl/dbias = 0.0346
# Layer 17, std of dl/dbias = 0.0296
# Layer 18, std of dl/dbias = 0.0300
# Layer 19, std of dl/dbias = 0.0268
# Layer 20, std of dl/dbias = 0.0330
# Layer 21, std of dl/dbias = 0.0303
# Layer 22, std of dl/dbias = 0.0269
# Layer 23, std of dl/dbias = 0.0278
# Layer 24, std of dl/dbias = 0.0244
# Layer 25, std of dl/dbias = 0.0251
# Layer 26, std of dl/dbias = 0.0349
# Layer 27, std of dl/dbias = 0.0289
# Layer 28, std of dl/dbias = 0.0320
# Layer 29, std of dl/dbias = 0.0346
# Layer 30, std of dl/dbias = 0.0374
# Layer 31, std of dl/dbias = 0.0384
# Layer 32, std of dl/dbias = 0.0371
# Layer 33, std of dl/dbias = 0.0393
# Layer 34, std of dl/dbias = 0.0442
# Layer 35, std of dl/dbias = 0.0412
# Layer 36, std of dl/dbias = 0.0417
# Layer 37, std of dl/dbias = 0.0367
# Layer 38, std of dl/dbias = 0.0354
# Layer 39, std of dl/dbias = 0.0317
# Layer 40, std of dl/dbias = 0.0354
# Layer 41, std of dl/dbias = 0.0351
# Layer 42, std of dl/dbias = 0.0423
# Layer 43, std of dl/dbias = 0.0464
# Layer 44, std of dl/dbias = 0.0508
# Layer 45, std of dl/dbias = 0.0548
# Layer 46, std of dl/dbias = 0.0526
# Layer 47, std of dl/dbias = 0.0536
# Layer 48, std of dl/dbias = 0.0492
# Layer 49, std of dl/dbias = 0.0418
# Layer 50, std of dl/dbias = 0.2030
#
# --- sigma_sq_omega = 0.024691 ---
# Layer  0, std of dl/dbias = 0.0169
# Layer  1, std of dl/dbias = 0.0164
# Layer  2, std of dl/dbias = 0.0174
# Layer  3, std of dl/dbias = 0.0200
# Layer  4, std of dl/dbias = 0.0197
# Layer  5, std of dl/dbias = 0.0185
# Layer  6, std of dl/dbias = 0.0193
# Layer  7, std of dl/dbias = 0.0204
# Layer  8, std of dl/dbias = 0.0183
# Layer  9, std of dl/dbias = 0.0185
# Layer 10, std of dl/dbias = 0.0212
# Layer 11, std of dl/dbias = 0.0217
# Layer 12, std of dl/dbias = 0.0220
# Layer 13, std of dl/dbias = 0.0202
# Layer 14, std of dl/dbias = 0.0211
# Layer 15, std of dl/dbias = 0.0223
# Layer 16, std of dl/dbias = 0.0204
# Layer 17, std of dl/dbias = 0.0175
# Layer 18, std of dl/dbias = 0.0179
# Layer 19, std of dl/dbias = 0.0161
# Layer 20, std of dl/dbias = 0.0199
# Layer 21, std of dl/dbias = 0.0184
# Layer 22, std of dl/dbias = 0.0164
# Layer 23, std of dl/dbias = 0.0171
# Layer 24, std of dl/dbias = 0.0151
# Layer 25, std of dl/dbias = 0.0156
# Layer 26, std of dl/dbias = 0.0219
# Layer 27, std of dl/dbias = 0.0183
# Layer 28, std of dl/dbias = 0.0204
# Layer 29, std of dl/dbias = 0.0221
# Layer 30, std of dl/dbias = 0.0241
# Layer 31, std of dl/dbias = 0.0249
# Layer 32, std of dl/dbias = 0.0242
# Layer 33, std of dl/dbias = 0.0257
# Layer 34, std of dl/dbias = 0.0291
# Layer 35, std of dl/dbias = 0.0273
# Layer 36, std of dl/dbias = 0.0279
# Layer 37, std of dl/dbias = 0.0247
# Layer 38, std of dl/dbias = 0.0240
# Layer 39, std of dl/dbias = 0.0216
# Layer 40, std of dl/dbias = 0.0242
# Layer 41, std of dl/dbias = 0.0242
# Layer 42, std of dl/dbias = 0.0293
# Layer 43, std of dl/dbias = 0.0323
# Layer 44, std of dl/dbias = 0.0357
# Layer 45, std of dl/dbias = 0.0387
# Layer 46, std of dl/dbias = 0.0373
# Layer 47, std of dl/dbias = 0.0383
# Layer 48, std of dl/dbias = 0.0354
# Layer 49, std of dl/dbias = 0.0303
# Layer 50, std of dl/dbias = 0.1479
