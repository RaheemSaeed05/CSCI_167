# %% [markdown]
# <a href="https://colab.research.google.com/github/RaheemSaeed05/CSCI_167/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-fuko5c0x
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-fuko5c0x
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=b1de1a999d818bfb5c73ba054bf8b718f36a849e34bdff0a5b4c9c8e31cb1f84
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7ic2725e/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.303491, train error 89.82,  test loss 2.303047, test error 89.25
# Epoch   100, train loss 2.024283, train error 76.60,  test loss 1.933988, test error 75.30
# Epoch   200, train loss 1.912932, train error 72.07,  test loss 1.750072, test error 69.53
# Epoch   300, train loss 1.908810, train error 72.05,  test loss 1.743976, test error 69.60
# Epoch   400, train loss 1.909654, train error 71.85,  test loss 1.740893, test error 69.25
# Epoch   500, train loss 1.908188, train error 71.78,  test loss 1.733578, test error 69.75
# Epoch   600, train loss 1.908214, train error 71.72,  test loss 1.737887, test error 69.40
# Epoch   700, train loss 1.908026, train error 71.45,  test loss 1.735418, test error 69.47
# Epoch   800, train loss 1.906937, train error 71.15,  test loss 1.736639, test error 69.62
# Epoch   900, train loss 1.907987, train error 71.55,  test loss 1.738446, test error 68.57
# Training model with   4 hidden variables
# Epoch     0, train loss 2.305593, train error 89.62,  test loss 2.309512, test error 90.03
# Epoch   100, train loss 1.737979, train error 63.88,  test loss 1.556326, test error 59.72
# Epoch   200, train loss 1.724752, train error 62.85,  test loss 1.518417, test error 59.28
# Epoch   300, train loss 1.720337, train error 62.28,  test loss 1.519599, test error 59.00
# Epoch   400, train loss 1.712427, train error 62.30,  test loss 1.513621, test error 58.67
# Epoch   500, train loss 1.709506, train error 62.42,  test loss 1.511371, test error 57.97
# Epoch   600, train loss 1.707664, train error 62.17,  test loss 1.507677, test error 58.45
# Epoch   700, train loss 1.711466, train error 61.72,  test loss 1.513773, test error 58.58
# Epoch   800, train loss 1.709354, train error 61.62,  test loss 1.509440, test error 59.05
# Epoch   900, train loss 1.724363, train error 62.55,  test loss 1.527951, test error 60.70
# Training model with   6 hidden variables
# Epoch     0, train loss 2.269516, train error 85.55,  test loss 2.258222, test error 85.75
# Epoch   100, train loss 1.730723, train error 64.20,  test loss 1.591379, test error 62.60
# Epoch   200, train loss 1.667724, train error 59.90,  test loss 1.493724, test error 57.97
# Epoch   300, train loss 1.648979, train error 59.20,  test loss 1.478273, test error 57.35
# Epoch   400, train loss 1.640618, train error 59.40,  test loss 1.481153, test error 56.62
# Epoch   500, train loss 1.637784, train error 59.85,  test loss 1.484153, test error 57.28
# Epoch   600, train loss 1.629207, train error 59.03,  test loss 1.480456, test error 57.03
# Epoch   700, train loss 1.627718, train error 59.33,  test loss 1.473160, test error 57.10
# Epoch   800, train loss 1.626540, train error 59.38,  test loss 1.477695, test error 57.55
# Epoch   900, train loss 1.628704, train error 58.42,  test loss 1.485213, test error 57.25
# Training model with   8 hidden variables
# Epoch     0, train loss 2.168656, train error 82.43,  test loss 2.116230, test error 80.93
# Epoch   100, train loss 1.582205, train error 55.60,  test loss 1.434737, test error 55.00
# Epoch   200, train loss 1.535987, train error 53.40,  test loss 1.401819, test error 52.70
# Epoch   300, train loss 1.506307, train error 52.40,  test loss 1.355477, test error 50.42
# Epoch   400, train loss 1.495701, train error 51.95,  test loss 1.362895, test error 50.83
# Epoch   500, train loss 1.485884, train error 51.85,  test loss 1.377439, test error 51.22
# Epoch   600, train loss 1.482087, train error 51.42,  test loss 1.377863, test error 51.15
# Epoch   700, train loss 1.481071, train error 50.95,  test loss 1.371371, test error 51.38
# Epoch   800, train loss 1.473504, train error 51.10,  test loss 1.377710, test error 51.55
# Epoch   900, train loss 1.478374, train error 51.00,  test loss 1.384281, test error 51.85
# Training model with  10 hidden variables
# Epoch     0, train loss 2.237061, train error 82.62,  test loss 2.227288, test error 82.65
# Epoch   100, train loss 1.550770, train error 54.20,  test loss 1.422504, test error 54.10
# Epoch   200, train loss 1.485961, train error 50.28,  test loss 1.325172, test error 50.50
# Epoch   300, train loss 1.457604, train error 48.60,  test loss 1.314615, test error 49.67
# Epoch   400, train loss 1.440241, train error 47.42,  test loss 1.299940, test error 48.42
# Epoch   500, train loss 1.435100, train error 47.50,  test loss 1.307742, test error 48.12
# Epoch   600, train loss 1.424845, train error 47.50,  test loss 1.305888, test error 48.00
# Epoch   700, train loss 1.416311, train error 47.12,  test loss 1.300050, test error 48.17
# Epoch   800, train loss 1.406324, train error 47.03,  test loss 1.299116, test error 48.00
# Epoch   900, train loss 1.402009, train error 46.30,  test loss 1.300846, test error 47.92
# Training model with  14 hidden variables
# Epoch     0, train loss 2.156073, train error 80.75,  test loss 2.125064, test error 80.95
# Epoch   100, train loss 1.374866, train error 46.15,  test loss 1.284775, test error 48.12
# Epoch   200, train loss 1.312200, train error 44.72,  test loss 1.269436, test error 47.05
# Epoch   300, train loss 1.266832, train error 42.83,  test loss 1.259342, test error 46.33
# Epoch   400, train loss 1.241624, train error 41.75,  test loss 1.270563, test error 46.75
# Epoch   500, train loss 1.235559, train error 42.03,  test loss 1.285980, test error 47.80
# Epoch   600, train loss 1.224816, train error 41.62,  test loss 1.297850, test error 47.70
# Epoch   700, train loss 1.221329, train error 41.58,  test loss 1.298413, test error 47.83
# Epoch   800, train loss 1.223230, train error 41.08,  test loss 1.307789, test error 48.28
# Epoch   900, train loss 1.214076, train error 40.75,  test loss 1.313557, test error 47.97
# Training model with  18 hidden variables
# Epoch     0, train loss 2.224943, train error 82.07,  test loss 2.218307, test error 81.85
# Epoch   100, train loss 1.393244, train error 47.60,  test loss 1.365793, test error 51.47
# Epoch   200, train loss 1.297686, train error 43.97,  test loss 1.366875, test error 50.92
# Epoch   300, train loss 1.254756, train error 42.67,  test loss 1.399804, test error 51.03
# Epoch   400, train loss 1.234949, train error 42.28,  test loss 1.431240, test error 51.38
# Epoch   500, train loss 1.226504, train error 41.90,  test loss 1.472330, test error 52.45
# Epoch   600, train loss 1.195138, train error 40.38,  test loss 1.470408, test error 52.70
# Epoch   700, train loss 1.185130, train error 40.22,  test loss 1.485167, test error 51.90
# Epoch   800, train loss 1.179356, train error 39.55,  test loss 1.511611, test error 53.20
# Epoch   900, train loss 1.164272, train error 39.30,  test loss 1.536547, test error 52.92
# Training model with  22 hidden variables
# Epoch     0, train loss 2.256340, train error 83.25,  test loss 2.240089, test error 82.03
# Epoch   100, train loss 1.307109, train error 43.12,  test loss 1.334450, test error 49.58
# Epoch   200, train loss 1.156024, train error 38.88,  test loss 1.370086, test error 50.03
# Epoch   300, train loss 1.093709, train error 36.65,  test loss 1.454018, test error 50.80
# Epoch   400, train loss 1.051423, train error 35.30,  test loss 1.519474, test error 51.10
# Epoch   500, train loss 1.024789, train error 34.50,  test loss 1.564331, test error 51.12
# Epoch   600, train loss 1.003616, train error 34.40,  test loss 1.627381, test error 51.85
# Epoch   700, train loss 0.990265, train error 34.18,  test loss 1.700109, test error 52.90
# Epoch   800, train loss 0.974417, train error 33.12,  test loss 1.741168, test error 52.95
# Epoch   900, train loss 0.969116, train error 32.95,  test loss 1.806671, test error 53.03
# Training model with  26 hidden variables
# Epoch     0, train loss 2.190191, train error 80.82,  test loss 2.176274, test error 80.07
# Epoch   100, train loss 1.199346, train error 39.22,  test loss 1.354636, test error 50.38
# Epoch   200, train loss 1.050075, train error 33.70,  test loss 1.416189, test error 49.22
# Epoch   300, train loss 0.989420, train error 32.15,  test loss 1.527373, test error 51.25
# Epoch   400, train loss 0.942107, train error 31.18,  test loss 1.614574, test error 50.38
# Epoch   500, train loss 0.911294, train error 30.05,  test loss 1.719388, test error 51.25
# Epoch   600, train loss 0.891929, train error 30.68,  test loss 1.817440, test error 51.95
# Epoch   700, train loss 0.872999, train error 29.62,  test loss 1.886830, test error 51.60
# Epoch   800, train loss 0.864793, train error 29.43,  test loss 1.955197, test error 52.62
# Epoch   900, train loss 0.868274, train error 29.28,  test loss 2.056685, test error 52.92
# Training model with  30 hidden variables
# Epoch     0, train loss 2.097142, train error 78.22,  test loss 2.063406, test error 77.93
# Epoch   100, train loss 1.109579, train error 36.25,  test loss 1.319183, test error 48.15
# Epoch   200, train loss 0.920492, train error 31.15,  test loss 1.539761, test error 51.70
# Epoch   300, train loss 0.842127, train error 28.47,  test loss 1.719180, test error 50.97
# Epoch   400, train loss 0.787157, train error 26.70,  test loss 1.881810, test error 51.45
# Epoch   500, train loss 0.742355, train error 25.18,  test loss 2.119269, test error 53.70
# Epoch   600, train loss 0.718786, train error 24.25,  test loss 2.251625, test error 54.67
# Epoch   700, train loss 0.676444, train error 22.38,  test loss 2.398690, test error 54.58
# Epoch   800, train loss 0.667934, train error 22.60,  test loss 2.509434, test error 54.67
# Epoch   900, train loss 0.649884, train error 22.32,  test loss 2.622036, test error 55.30
# Training model with  35 hidden variables
# Epoch     0, train loss 2.094144, train error 77.78,  test loss 2.032186, test error 76.03
# Epoch   100, train loss 1.071568, train error 35.03,  test loss 1.407426, test error 50.47
# Epoch   200, train loss 0.840918, train error 28.65,  test loss 1.691394, test error 52.75
# Epoch   300, train loss 0.718819, train error 24.45,  test loss 2.019897, test error 54.62
# Epoch   400, train loss 0.641654, train error 21.57,  test loss 2.328077, test error 55.35
# Epoch   500, train loss 0.566884, train error 18.68,  test loss 2.700596, test error 55.30
# Epoch   600, train loss 0.558638, train error 18.93,  test loss 3.039612, test error 56.62
# Epoch   700, train loss 0.493111, train error 15.93,  test loss 3.345238, test error 57.08
# Epoch   800, train loss 0.471310, train error 15.43,  test loss 3.671683, test error 58.17
# Epoch   900, train loss 0.468161, train error 16.07,  test loss 3.916312, test error 58.30
# Training model with  40 hidden variables
# Epoch     0, train loss 2.088594, train error 78.10,  test loss 2.026724, test error 77.25
# Epoch   100, train loss 0.910347, train error 28.80,  test loss 1.442836, test error 48.38
# Epoch   200, train loss 0.623308, train error 19.35,  test loss 1.947411, test error 52.12
# Epoch   300, train loss 0.495837, train error 16.50,  test loss 2.557093, test error 53.62
# Epoch   400, train loss 0.417051, train error 14.05,  test loss 3.213812, test error 54.75
# Epoch   500, train loss 0.351961, train error 11.75,  test loss 3.886023, test error 56.60
# Epoch   600, train loss 0.359507, train error 12.75,  test loss 4.546733, test error 57.28
# Epoch   700, train loss 0.360064, train error 12.75,  test loss 5.074140, test error 56.38
# Epoch   800, train loss 0.258876, train error 9.15,  test loss 5.744022, test error 57.83
# Epoch   900, train loss 0.254351, train error 9.00,  test loss 6.338176, test error 57.12
# Training model with  45 hidden variables
# Epoch     0, train loss 2.107386, train error 78.78,  test loss 2.066864, test error 76.68
# Epoch   100, train loss 0.774124, train error 24.65,  test loss 1.487138, test error 49.58
# Epoch   200, train loss 0.477341, train error 14.80,  test loss 2.215015, test error 52.10
# Epoch   300, train loss 0.305322, train error 9.05,  test loss 3.215175, test error 53.88
# Epoch   400, train loss 0.178162, train error 5.28,  test loss 4.505394, test error 54.17
# Epoch   500, train loss 0.153039, train error 5.18,  test loss 5.851968, test error 55.08
# Epoch   600, train loss 0.166006, train error 5.65,  test loss 7.028945, test error 55.95
# Epoch   700, train loss 0.013207, train error 0.03,  test loss 8.052152, test error 55.65
# Epoch   800, train loss 0.007057, train error 0.00,  test loss 8.736234, test error 56.00
# Epoch   900, train loss 0.005124, train error 0.00,  test loss 9.211662, test error 55.90
# Training model with  50 hidden variables
# Epoch     0, train loss 2.076621, train error 77.62,  test loss 2.046582, test error 77.38
# Epoch   100, train loss 0.755537, train error 23.78,  test loss 1.573699, test error 50.00
# Epoch   200, train loss 0.362838, train error 10.18,  test loss 2.474116, test error 52.38
# Epoch   300, train loss 0.199975, train error 5.28,  test loss 3.827074, test error 53.62
# Epoch   400, train loss 0.049762, train error 0.25,  test loss 5.485182, test error 55.45
# Epoch   500, train loss 0.015831, train error 0.00,  test loss 6.594624, test error 55.70
# Epoch   600, train loss 0.009605, train error 0.00,  test loss 7.287729, test error 55.33
# Epoch   700, train loss 0.006713, train error 0.00,  test loss 7.804615, test error 55.38
# Epoch   800, train loss 0.005139, train error 0.00,  test loss 8.206399, test error 55.28
# Epoch   900, train loss 0.004106, train error 0.00,  test loss 8.539467, test error 55.25
# Training model with  55 hidden variables
# Epoch     0, train loss 2.033980, train error 76.20,  test loss 1.970858, test error 75.85
# Epoch   100, train loss 0.683141, train error 20.45,  test loss 1.572926, test error 50.42
# Epoch   200, train loss 0.275055, train error 7.50,  test loss 2.754938, test error 52.72
# Epoch   300, train loss 0.060589, train error 0.30,  test loss 4.537212, test error 54.83
# Epoch   400, train loss 0.016961, train error 0.00,  test loss 5.695859, test error 55.30
# Epoch   500, train loss 0.009320, train error 0.00,  test loss 6.381357, test error 55.30
# Epoch   600, train loss 0.006265, train error 0.00,  test loss 6.857643, test error 55.22
# Epoch   700, train loss 0.004626, train error 0.00,  test loss 7.236197, test error 55.25
# Epoch   800, train loss 0.003638, train error 0.00,  test loss 7.534739, test error 55.15
# Epoch   900, train loss 0.002970, train error 0.00,  test loss 7.784322, test error 55.20
# Training model with  60 hidden variables
# Epoch     0, train loss 2.022775, train error 75.95,  test loss 1.971827, test error 76.32
# Epoch   100, train loss 0.555013, train error 16.12,  test loss 1.726844, test error 50.67
# Epoch   200, train loss 0.107628, train error 1.03,  test loss 3.327333, test error 53.90
# Epoch   300, train loss 0.020125, train error 0.00,  test loss 4.664465, test error 54.17
# Epoch   400, train loss 0.009392, train error 0.00,  test loss 5.344485, test error 54.47
# Epoch   500, train loss 0.005920, train error 0.00,  test loss 5.785988, test error 54.22
# Epoch   600, train loss 0.004252, train error 0.00,  test loss 6.120126, test error 54.25
# Epoch   700, train loss 0.003241, train error 0.00,  test loss 6.379868, test error 54.22
# Epoch   800, train loss 0.002609, train error 0.00,  test loss 6.597551, test error 54.22
# Epoch   900, train loss 0.002173, train error 0.00,  test loss 6.779397, test error 54.17
# Training model with  70 hidden variables
# Epoch     0, train loss 2.038737, train error 75.75,  test loss 1.996705, test error 76.85
# Epoch   100, train loss 0.428742, train error 12.18,  test loss 1.915690, test error 50.58
# Epoch   200, train loss 0.046036, train error 0.05,  test loss 3.509482, test error 52.70
# Epoch   300, train loss 0.012756, train error 0.00,  test loss 4.393230, test error 52.30
# Epoch   400, train loss 0.006920, train error 0.00,  test loss 4.875510, test error 52.45
# Epoch   500, train loss 0.004581, train error 0.00,  test loss 5.208025, test error 52.25
# Epoch   600, train loss 0.003361, train error 0.00,  test loss 5.455940, test error 52.35
# Epoch   700, train loss 0.002622, train error 0.00,  test loss 5.660700, test error 52.55
# Epoch   800, train loss 0.002133, train error 0.00,  test loss 5.829190, test error 52.58
# Epoch   900, train loss 0.001786, train error 0.00,  test loss 5.971505, test error 52.65
# Training model with  80 hidden variables
# Epoch     0, train loss 2.013934, train error 74.82,  test loss 1.962378, test error 74.65
# Epoch   100, train loss 0.267225, train error 6.20,  test loss 2.055545, test error 50.58
# Epoch   200, train loss 0.021526, train error 0.00,  test loss 3.399606, test error 52.80
# Epoch   300, train loss 0.008334, train error 0.00,  test loss 3.969547, test error 52.53
# Epoch   400, train loss 0.004862, train error 0.00,  test loss 4.300430, test error 52.58
# Epoch   500, train loss 0.003350, train error 0.00,  test loss 4.538427, test error 52.45
# Epoch   600, train loss 0.002521, train error 0.00,  test loss 4.715454, test error 52.47
# Epoch   700, train loss 0.001993, train error 0.00,  test loss 4.866995, test error 52.55
# Epoch   800, train loss 0.001639, train error 0.00,  test loss 4.992815, test error 52.50
# Epoch   900, train loss 0.001384, train error 0.00,  test loss 5.099981, test error 52.58
# Training model with  90 hidden variables
# Epoch     0, train loss 2.019772, train error 74.47,  test loss 1.972671, test error 75.47
# Epoch   100, train loss 0.153294, train error 1.25,  test loss 2.256898, test error 53.55
# Epoch   200, train loss 0.015275, train error 0.00,  test loss 3.356808, test error 53.33
# Epoch   300, train loss 0.006714, train error 0.00,  test loss 3.812385, test error 53.53
# Epoch   400, train loss 0.004069, train error 0.00,  test loss 4.094097, test error 53.22
# Epoch   500, train loss 0.002857, train error 0.00,  test loss 4.294847, test error 53.33
# Epoch   600, train loss 0.002171, train error 0.00,  test loss 4.453717, test error 53.42
# Epoch   700, train loss 0.001735, train error 0.00,  test loss 4.584360, test error 53.45
# Epoch   800, train loss 0.001437, train error 0.00,  test loss 4.692767, test error 53.53
# Epoch   900, train loss 0.001219, train error 0.00,  test loss 4.789546, test error 53.53
# Training model with 100 hidden variables
# Epoch     0, train loss 1.991693, train error 74.53,  test loss 1.914604, test error 74.53
# Epoch   100, train loss 0.094524, train error 0.30,  test loss 2.226663, test error 50.65
# Epoch   200, train loss 0.012367, train error 0.00,  test loss 3.092885, test error 50.47
# Epoch   300, train loss 0.005768, train error 0.00,  test loss 3.453547, test error 50.30
# Epoch   400, train loss 0.003597, train error 0.00,  test loss 3.681913, test error 50.40
# Epoch   500, train loss 0.002556, train error 0.00,  test loss 3.848578, test error 50.55
# Epoch   600, train loss 0.001957, train error 0.00,  test loss 3.980229, test error 50.62
# Epoch   700, train loss 0.001570, train error 0.00,  test loss 4.087435, test error 50.67
# Epoch   800, train loss 0.001304, train error 0.00,  test loss 4.179681, test error 50.67
# Epoch   900, train loss 0.001110, train error 0.00,  test loss 4.257512, test error 50.72
# Training model with 120 hidden variables
# Epoch     0, train loss 1.965856, train error 71.90,  test loss 1.879681, test error 72.55
# Epoch   100, train loss 0.048996, train error 0.00,  test loss 2.207392, test error 51.70
# Epoch   200, train loss 0.009392, train error 0.00,  test loss 2.809918, test error 51.20
# Epoch   300, train loss 0.004672, train error 0.00,  test loss 3.086651, test error 51.25
# Epoch   400, train loss 0.002999, train error 0.00,  test loss 3.262638, test error 51.15
# Epoch   500, train loss 0.002161, train error 0.00,  test loss 3.393641, test error 51.17
# Epoch   600, train loss 0.001671, train error 0.00,  test loss 3.497216, test error 51.25
# Epoch   700, train loss 0.001352, train error 0.00,  test loss 3.582232, test error 51.22
# Epoch   800, train loss 0.001129, train error 0.00,  test loss 3.654534, test error 51.35
# Epoch   900, train loss 0.000965, train error 0.00,  test loss 3.717483, test error 51.22
# Training model with 140 hidden variables
# Epoch     0, train loss 1.946008, train error 71.18,  test loss 1.866866, test error 70.57
# Epoch   100, train loss 0.037894, train error 0.00,  test loss 2.185494, test error 50.30
# Epoch   200, train loss 0.008213, train error 0.00,  test loss 2.666748, test error 49.67
# Epoch   300, train loss 0.004175, train error 0.00,  test loss 2.901693, test error 49.80
# Epoch   400, train loss 0.002713, train error 0.00,  test loss 3.056624, test error 49.75
# Epoch   500, train loss 0.001971, train error 0.00,  test loss 3.170723, test error 49.85
# Epoch   600, train loss 0.001531, train error 0.00,  test loss 3.261881, test error 49.83
# Epoch   700, train loss 0.001243, train error 0.00,  test loss 3.336576, test error 49.78
# Epoch   800, train loss 0.001040, train error 0.00,  test loss 3.401437, test error 49.85
# Epoch   900, train loss 0.000891, train error 0.00,  test loss 3.457577, test error 49.80
# Training model with 160 hidden variables
# Epoch     0, train loss 1.941152, train error 72.20,  test loss 1.886155, test error 74.43
# Epoch   100, train loss 0.027849, train error 0.00,  test loss 2.085510, test error 48.03
# Epoch   200, train loss 0.007002, train error 0.00,  test loss 2.461220, test error 47.67
# Epoch   300, train loss 0.003693, train error 0.00,  test loss 2.653439, test error 47.70
# Epoch   400, train loss 0.002437, train error 0.00,  test loss 2.779827, test error 47.62
# Epoch   500, train loss 0.001784, train error 0.00,  test loss 2.873440, test error 47.62
# Epoch   600, train loss 0.001395, train error 0.00,  test loss 2.948122, test error 47.75
# Epoch   700, train loss 0.001137, train error 0.00,  test loss 3.010568, test error 47.90
# Epoch   800, train loss 0.000955, train error 0.00,  test loss 3.064613, test error 47.85
# Epoch   900, train loss 0.000820, train error 0.00,  test loss 3.111590, test error 47.85
# Training model with 180 hidden variables
# Epoch     0, train loss 1.914557, train error 69.80,  test loss 1.844665, test error 71.20
# Epoch   100, train loss 0.023881, train error 0.00,  test loss 2.059050, test error 48.17
# Epoch   200, train loss 0.006482, train error 0.00,  test loss 2.417474, test error 48.38
# Epoch   300, train loss 0.003483, train error 0.00,  test loss 2.596140, test error 48.20
# Epoch   400, train loss 0.002311, train error 0.00,  test loss 2.717088, test error 48.05
# Epoch   500, train loss 0.001703, train error 0.00,  test loss 2.808388, test error 48.20
# Epoch   600, train loss 0.001335, train error 0.00,  test loss 2.880955, test error 48.15
# Epoch   700, train loss 0.001091, train error 0.00,  test loss 2.941734, test error 48.20
# Epoch   800, train loss 0.000917, train error 0.00,  test loss 2.993655, test error 48.22
# Epoch   900, train loss 0.000789, train error 0.00,  test loss 3.039257, test error 48.10
# Training model with 200 hidden variables
# Epoch     0, train loss 1.886054, train error 68.03,  test loss 1.808135, test error 70.50
# Epoch   100, train loss 0.021513, train error 0.00,  test loss 2.004319, test error 47.62
# Epoch   200, train loss 0.006150, train error 0.00,  test loss 2.314159, test error 47.38
# Epoch   300, train loss 0.003341, train error 0.00,  test loss 2.476916, test error 47.60
# Epoch   400, train loss 0.002230, train error 0.00,  test loss 2.586709, test error 47.58
# Epoch   500, train loss 0.001647, train error 0.00,  test loss 2.668843, test error 47.50
# Epoch   600, train loss 0.001294, train error 0.00,  test loss 2.734786, test error 47.47
# Epoch   700, train loss 0.001058, train error 0.00,  test loss 2.789177, test error 47.45
# Epoch   800, train loss 0.000891, train error 0.00,  test loss 2.836774, test error 47.53
# Epoch   900, train loss 0.000767, train error 0.00,  test loss 2.877984, test error 47.40
# Training model with 250 hidden variables
# Epoch     0, train loss 1.915801, train error 70.03,  test loss 1.839354, test error 71.88
# Epoch   100, train loss 0.017316, train error 0.00,  test loss 1.901638, test error 45.97
# Epoch   200, train loss 0.005395, train error 0.00,  test loss 2.156616, test error 45.97
# Epoch   300, train loss 0.003006, train error 0.00,  test loss 2.292354, test error 45.72
# Epoch   400, train loss 0.002030, train error 0.00,  test loss 2.384531, test error 45.78
# Epoch   500, train loss 0.001511, train error 0.00,  test loss 2.455158, test error 45.67
# Epoch   600, train loss 0.001193, train error 0.00,  test loss 2.511613, test error 45.47
# Epoch   700, train loss 0.000979, train error 0.00,  test loss 2.558767, test error 45.58
# Epoch   800, train loss 0.000827, train error 0.00,  test loss 2.599240, test error 45.58
# Epoch   900, train loss 0.000713, train error 0.00,  test loss 2.635464, test error 45.60
# Training model with 300 hidden variables
# Epoch     0, train loss 1.864018, train error 68.38,  test loss 1.790816, test error 69.68
# Epoch   100, train loss 0.014158, train error 0.00,  test loss 1.836928, test error 46.88
# Epoch   200, train loss 0.004761, train error 0.00,  test loss 2.047392, test error 46.90
# Epoch   300, train loss 0.002704, train error 0.00,  test loss 2.161753, test error 46.90
# Epoch   400, train loss 0.001842, train error 0.00,  test loss 2.242080, test error 46.88
# Epoch   500, train loss 0.001380, train error 0.00,  test loss 2.302250, test error 46.83
# Epoch   600, train loss 0.001094, train error 0.00,  test loss 2.350906, test error 46.75
# Epoch   700, train loss 0.000900, train error 0.00,  test loss 2.392395, test error 46.88
# Epoch   800, train loss 0.000762, train error 0.00,  test loss 2.427500, test error 46.92
# Epoch   900, train loss 0.000659, train error 0.00,  test loss 2.458711, test error 47.00
# Training model with 400 hidden variables
# Epoch     0, train loss 1.816656, train error 64.65,  test loss 1.742738, test error 67.97
# Epoch   100, train loss 0.011380, train error 0.00,  test loss 1.726219, test error 45.50
# Epoch   200, train loss 0.004098, train error 0.00,  test loss 1.895594, test error 45.22
# Epoch   300, train loss 0.002379, train error 0.00,  test loss 1.990645, test error 45.33
# Epoch   400, train loss 0.001641, train error 0.00,  test loss 2.056008, test error 45.25
# Epoch   500, train loss 0.001237, train error 0.00,  test loss 2.106908, test error 45.22
# Epoch   600, train loss 0.000986, train error 0.00,  test loss 2.148202, test error 45.17
# Epoch   700, train loss 0.000815, train error 0.00,  test loss 2.182554, test error 45.20
# Epoch   800, train loss 0.000692, train error 0.00,  test loss 2.212940, test error 45.15
# Epoch   900, train loss 0.000600, train error 0.00,  test loss 2.239295, test error 45.22

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
